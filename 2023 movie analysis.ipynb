# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data =pd.read_csv(r"C:\Users\ASUS\Desktop\Movies_dataset.csv")

# %%
data.head()
# Out:
#    index                                title original_language release_date  \
# 0      0  Spider-Man: Across the Spider-Verse                en   31-05-2023
# 1      1     Transformers: Rise of the Beasts                en   06-06-2023
# 2      2                            The Flash                en   13-06-2023
# 3      3                     No Hard Feelings                en   15-06-2023
# 4      4                               Barbie                en   19-07-2023
#
#    popularity  vote_average  vote_count  \
# 0    3368.627           8.5        3386
# 1    2160.316           7.5        2747
# 2    2108.713           7.0        2305
# 3    1978.358           7.1         562
# 4    1976.513           7.5        3013
#
#                                             overview
# 0  After reuniting with Gwen Stacy, Brooklyn’s fu...
# 1  When a new threat capable of destroying the en...
# 2  When his attempt to save his family inadverten...
# ...

# %%
data.tail(10)
# Out:
#       index                        title original_language release_date  \
# 9990   9990                  Frankenfish                en   09-10-2004
# 9991   9991                 Summer of 84                en   10-08-2018
# 9992   9992       Fist of the North Star                ja   08-03-1986
# 9993   9993         My Friend's Sister 3                ko   14-03-2019
# 9994   9994  Leprechaun: Back 2 tha Hood                en   30-12-2003
# 9995   9995     Porky's II: The Next Day                en   24-06-1983
# 9996   9996                 Nobody Knows                ja   07-08-2004
# 9997   9997                   Rollerball                en   25-06-1975
# 9998   9998               On Golden Pond                en   01-12-1981
# 9999   9999              OMG: Oh My God!                hi   28-09-2012
#
#       popularity  vote_average  vote_count  \
# 9990      12.621           5.7         127
# 9991      12.619           6.9        1159
# ...

# %%
data.shape
# Out:
# (10000, 8)

# %%
print("number of rows",data.shape[0])
print("number of columns",data.shape[1])
# Out:
# number of rows 10000
# number of columns 8

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              10000 non-null  int64
#  1   title              10000 non-null  object
#  2   original_language  10000 non-null  object
#  3   release_date       9982 non-null   object
#  4   popularity         10000 non-null  float64
#  5   vote_average       10000 non-null  float64
#  6   vote_count         10000 non-null  int64
#  7   overview           9905 non-null   object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 625.1+ KB

# %%
print("any missing values?",data.isnull().values.any())
# Out:
# any missing values? True

# %%
data.isnull().sum()
# Out:
# index                 0
# title                 0
# original_language     0
# release_date         18
# popularity            0
# vote_average          0
# vote_count            0
# overview             95
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
per_missing = data.isnull().sum()*100/len(data)
per_missing
# Out:
# index                0.00
# title                0.00
# original_language    0.00
# release_date         0.18
# popularity           0.00
# vote_average         0.00
# vote_count           0.00
# overview             0.95
# dtype: float64

# %%
data.dropna(axis=0)
# Out:
#       index                                title original_language  \
# 0         0  Spider-Man: Across the Spider-Verse                en
# 1         1     Transformers: Rise of the Beasts                en
# 2         2                            The Flash                en
# 3         3                     No Hard Feelings                en
# 4         4                               Barbie                en
# ...     ...                                  ...               ...
# 9995   9995             Porky's II: The Next Day                en
# 9996   9996                         Nobody Knows                ja
# 9997   9997                           Rollerball                en
# 9998   9998                       On Golden Pond                en
# 9999   9999                      OMG: Oh My God!                hi
#
#      release_date  popularity  vote_average  vote_count  \
# 0      31-05-2023    3368.627           8.5        3386
# ...

# %%
dup_data = data.duplicated().any()

# %%
print("are there any duplicate values?",dup_data)
# Out:
# are there any duplicate values? False

# %%
data = data.drop_duplicates()
data
# Out:
#       index                                title original_language  \
# 0         0  Spider-Man: Across the Spider-Verse                en
# 1         1     Transformers: Rise of the Beasts                en
# 2         2                            The Flash                en
# 3         3                     No Hard Feelings                en
# 4         4                               Barbie                en
# ...     ...                                  ...               ...
# 9995   9995             Porky's II: The Next Day                en
# 9996   9996                         Nobody Knows                ja
# 9997   9997                           Rollerball                en
# 9998   9998                       On Golden Pond                en
# 9999   9999                      OMG: Oh My God!                hi
#
#      release_date  popularity  vote_average  vote_count  \
# 0      31-05-2023    3368.627           8.5        3386
# ...

# %%
data.describe(include="all")
# Out:
#               index       title original_language release_date    popularity  \
# count   10000.00000       10000             10000         9982  10000.000000
# unique          NaN        9261                48         5800           NaN
# top             NaN  Cinderella                en   15-08-2023           NaN
# freq            NaN           4              7168           68           NaN
# mean     4999.50000         NaN               NaN          NaN     32.311563
# std      2886.89568         NaN               NaN          NaN     83.572929
# min         0.00000         NaN               NaN          NaN      8.128000
# 25%      2499.75000         NaN               NaN          NaN     14.931000
# 50%      4999.50000         NaN               NaN          NaN     19.240500
# 75%      7499.25000         NaN               NaN          NaN     28.886500
# max      9999.00000         NaN               NaN          NaN   3368.627000
#
#         vote_average    vote_count  \
# ...

# %%
data.columns
# Out:
# Index(['index', 'title', 'original_language', 'release_date', 'popularity',
#        'vote_average', 'vote_count', 'overview'],
#       dtype='object')

# %%
data[data['vote_average']>=1.2]['title']
# Out:
# 0       Spider-Man: Across the Spider-Verse
# 1          Transformers: Rise of the Beasts
# 2                                 The Flash
# 3                          No Hard Feelings
# 4                                    Barbie
#                        ...
# 9995               Porky's II: The Next Day
# 9996                           Nobody Knows
# 9997                             Rollerball
# 9998                         On Golden Pond
# 9999                        OMG: Oh My God!
# Name: title, Length: 9686, dtype: object

# %%
data.groupby('release_date')['vote_count'].mean().sort_values(ascending = False)
# Out:
# release_date
# 05-11-2014    32159.0
# 14-07-2008    30317.0
# 15-12-2009    29611.0
# 09-02-2016    28734.0
# 15-10-1999    26958.0
#                ...
# 21-09-2023        0.0
# 29-08-1981        0.0
# 08-11-2023        0.0
# 25-09-2023        0.0
# 09-11-2013        0.0
# Name: vote_count, Length: 5800, dtype: float64

# %%
sns.barplot(x='release_date',y= 'vote_count',data=data)
plt.title("votes by release_date")
# Out:
# Text(0.5, 1.0, 'votes by release_date')

# %%
data.columns
# Out:
# Index(['index', 'title', 'original_language', 'release_date', 'popularity',
#        'vote_average', 'vote_count', 'overview'],
#       dtype='object')

# %%
data.groupby('release_date')['popularity'].mean().sort_values(ascending=False)
# Out:
# release_date
# 05-07-2023    1222.7170
# 31-05-2023    1150.5980
# 13-06-2023    1099.7950
# 06-06-2023    1092.1460
# 14-06-2023     887.9055
#                 ...
# 28-11-2013      10.7680
# 27-02-2015      10.4950
# 19-01-2014       9.7820
# 21-11-2014       9.6560
# 27-12-1985       8.7240
# Name: popularity, Length: 5800, dtype: float64

# %%
sns.barplot(x='release_date',y='popularity',data=data)
plt.title("Revenue by year")
plt.show()
